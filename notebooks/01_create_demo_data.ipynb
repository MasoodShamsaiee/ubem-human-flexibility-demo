# %% [markdown]
# # Create demo-safe data
#
# The conference app uses small CSV files in `data/` rather than private or large research outputs. The schema preserves the public synthetic-population output columns and DSM proxy names reviewed from the source repos.
#
# Regenerate or expand the data by editing `data/demo_synthetic_population.csv` and `data/demo_dsm_profiles.csv`, then rerun the Streamlit app.
